# %% [markdown]
# <p align="center">
#   <img width='275' src="https://user-images.githubusercontent.com/8030363/195494428-aef60f6c-5211-43ac-8650-ddaa05bfa34a.png" />
# </p>
#
# ***
# ***
#
# # Tutorial: Knowledge Graph Entity Search
#
# ***
#
# **Author:** [TJCallahan](http://tiffanycallahan.com/)
# **GitHub Repository:** [PheKnowLator](https://github.com/callahantiff/PheKnowLator/wiki)
# **Wiki Page:** [Drug Safety Tutorial](https://github.com/callahantiff/PheKnowLator/wiki/KG-based-Investigation-of-Drug-Outcome-Pairs)
# <!-- **Tutorial Slides:** [PheKnowLator_Tutorial_EntitySearch](https://docs.google.com/presentation/d/19oc41CFILLlf0HjJfFJlUER-4wt1YV-BItkqWbI4NwU/edit?usp=sharing)
# **Release:** **[v3.0.2](https://github.com/callahantiff/PheKnowLator/wiki/v3.0.0)**   -->
#
# <br>
#
# ## Purpose
# The goal of this notebook is to explore different ways to examine relationships between different types of entities in a `PheKnowLator` knowledge graph. A figure depicting the general workflow that is used in this demo is shown below. The objective is to search `OMOP` (Observational Medical Outcomes Partnership) common data model (CDM) concepts against entities in a `PheKnowLator` knowledge graph, which requires mappings from `OMOP2OBO`. Each of these resources will be introduced and described in this tutorial.
#
# <br>
#
# ![](https://user-images.githubusercontent.com/8030363/195580089-872994c4-6498-491c-90e6-51d4203aec93.png)
#
# <br>
#
# In this tutorial, we will demonstrate the utility of this workflow by examining three different types of adverse event relationships will be explored:
#
# **Known Relationships**
# - **Positive:** *Known drug-outcome pairs:*
#   - `lisinopril` ([OMOP:1308216](https://athena.ohdsi.org/search-terms/terms/1308216)) and `myocardial infarction` ([OMOP:4329847](https://athena.ohdsi.org/search-terms/terms/4329847))
#
# - **Negative:** *Drug-outcome pairs known to not be related:*
#   - `lisinopril` ([OMOP:1308216](https://athena.ohdsi.org/search-terms/terms/1308216)) and `contact dermatitis` ([OMOP:134438](https://athena.ohdsi.org/search-terms/terms/134438))
#   - `lisinopril` ([OMOP:1308216](https://athena.ohdsi.org/search-terms/terms/1308216)) and `ingrown toenails` ([OMOP:4290993](https://athena.ohdsi.org/search-terms/terms/4290993))
#   - `lisinopril` ([OMOP:1308216](https://athena.ohdsi.org/search-terms/terms/1308216)) and `presbyopia` ([OMOP:373478](https://athena.ohdsi.org/search-terms/terms/373478))
#
# **Unknown Relationships**
# *Drug-outcome pairs with no known relationship:*
# - `ivermectin` ([OMOP:42593521](https://athena.ohdsi.org/search-terms/terms/42593521)) and `neurotoxicity` ([OMOP:4024301](https://athena.ohdsi.org/search-terms/terms/4024301))
#
# <br>
#
# ___
#
# ### Notebook Organization
# - [Set-Up Environment](#set-environment)
# - [Knowledge Graph Data](#kg-data)
#
# **Prerequisites**
# - [OMOP2OBO Mappings](#omop2obo-mappings)
# - [PheKnowLator Knowledge Graph - Schema](#pkt-schema)
#
# **Drug Safety Task - Knowledge Graph-based Drug Safety**
# - [Knowledge-based Characterization](#kg-characterization)
#     - [Node-Level](#node-level)
#     - [Path-Level](#path-level)
#
# ***
# ***
#
# <br>

# %% [markdown]
# <br>
#
# ***
# ## Set-Up Environment  <a class="anchor" id="set-environment"></a>
# ***
# ___

# %%
# # uncomment and run to install any required modules from notebooks/requirements.txt
# import sys
# !{sys.executable} -m pip install -r ../../notebooks/requirements.txt

# %%
# run only if running a local version (i.e., forked from GitHub) of pkt_kg
import sys
sys.path.append('../../../')

# %% [markdown]
# ⚠️ **Installing graphviz** ⚠️
# graphviz can be a tricky library to install, which is why it is not automatically handled for the user via `notebooks/requirements.txt`. If you want to install this, I recommend using the last comment in the following [StackOverflow](https://stackoverflow.com/questions/69377104/unable-to-execute-dot-command-after-installation-of-graphviz-there-is-no-layou) post, but make sure you understand what it is doing before running any of the code. The only thing this impacts is the rendering of network visualizations. Simply skip the visualization code chunks if you are unable to install `graphviz`.

# %%
# import needed libraries
import glob
import json
import networkx as nx
import os
import pandas as pd
import pickle
import random
import re

from entity_search import *
from pyvis.network import Network
from rdflib import Graph, Namespace, URIRef, BNode, Literal
from rdflib.namespace import RDFS
from tqdm.notebook import tqdm
from typing import Callable, Dict, List, Optional, Union

# temp work around to avoid logging error
try: from pkt_kg.utils import *
except FileNotFoundError: from pkt_kg.utils import *

# create namespace for OBO ontologies
obo = Namespace('http://purl.obolibrary.org/obo/')

# %% [markdown]
# <br>
#
# ***
#
# ## Knowledge Graph Data  <a class="anchor" id="kg-data"></a>
# ***
#
# #### *How to access PheKnowLator Data*
# ___
#
# This notebook was built using a `v3.0.2` OWL-NETS-abstracted subclass-based build with inverse relations, which is publicly available and can be downloaded using the following links:
# - [PheKnowLator_v3.0.2_full_subclass_inverseRelations_OWLNETS_NetworkxMultiDiGraph.gpickle](https://zenodo.org/records/10056198/files/PheKnowLator_v3.0.2_full_subclass_inverseRelations_OWLNETS_SUBCLASS_purified_NetworkxMultiDiGraph.gpickle.tar.gz?download=1)
# - [PheKnowLator_v3.0.2_full_subclass_inverseRelations_OWLNETS_NodeLabels.txt](https://zenodo.org/records/10056198/files/PheKnowLator_v3.0.2_full_subclass_inverseRelations_OWLNETS_NodeLabels.txt.tar.gz?download=1)

# %% [markdown]
# ### Download Data
# ***
#
# The knowledge graph data is publicly available and downloaded from the PheKnowLator project's Zenodo Archive: https://zenodo.org/doi/10.5281/zenodo.7030039. Data will be downloaded to the `tutorials/entity_search/data` directory.

# %%
# notebook will create a temporary directory and will download data to it
write_location = 'data/'
if not os.path.exists(write_location): os.mkdir(write_location)

# %%
# download data to the data directory
data_urls = [
    'https://zenodo.org/records/10056198/files/PheKnowLator_v3.0.2_full_subclass_inverseRelations_OWLNETS_SUBCLASS_purified_NetworkxMultiDiGraph.gpickle.tar.gz?download=1',
    'https://zenodo.org/records/10056198/files/PheKnowLator_v3.0.2_full_subclass_inverseRelations_OWLNETS_NodeLabels.txt.tar.gz?download=1'
]

# for url in data_urls:
#     file_name = re.sub(r'\?.*', '', url.split('/')[-1])
#     # This seem to be a bug?
#     # file_name = re.sub(r'\?.*', '', url.split('/')[-1])
#     if not os.path.exists(write_location + file_name): data_downloader(url, write_location, file_name)
    
#     zip_pat = '.gz|.zip'
#     fname = re.sub(zip_pat, '', file_name) if file_name != '' else re.sub(zip_pat, '', url.split('/')[-1])
#     print("File written to: ", fname)

# %%
import tarfile

for url in data_urls:
    file_name = re.sub(r'\?.*', '', url.split('/')[-1]).replace('.gz', '')
    with tarfile.open(write_location + file_name, 'r') as tar:
        # Extract the contents of the tar file
        print(f"Extracting {write_location + file_name}...")
        tar.extractall(path=write_location)
# Out:
# Extracting data/PheKnowLator_v3.0.2_full_subclass_inverseRelations_OWLNETS_SUBCLASS_purified_NetworkxMultiDiGraph.gpickle.tar...
# Extracting data/PheKnowLator_v3.0.2_full_subclass_inverseRelations_OWLNETS_NodeLabels.txt.tar...

# %% [markdown]
# ### Load Data
# ***
#
# The knowledge graph will be loaded as a `networkx` MultiDiGraph object and the node labels will be read in and converted to a dictionary to enable easy access to node labels and other relevant metadata.

# %% [markdown]
# #### Knowledge Graph
#
# Note that this file is large and can take up to 2 minutes to load on a laptop with 16GB of Ram.

# %%
# load the knowledge graph
file_name = write_location + re.sub(r'\?.*', '', data_urls[0].split('/')[-1])# data_urls[0].split('/')[-1]
# but this seem wrong we need to remove the .gz,
file_name = file_name.replace('.tar.gz', '')
print('Loading knowledge graph from {}'.format(file_name))
with open(file_name, 'rb') as f:
    kg = pickle.load(f)

undirected_kg = nx.to_undirected(kg)
print('The knowledge graph contains {} nodes and {} edges'.format(len(kg.nodes()), len(kg.edges())))
# Out:
# Loading knowledge graph from data/PheKnowLator_v3.0.2_full_subclass_inverseRelations_OWLNETS_SUBCLASS_purified_NetworkxMultiDiGraph.gpickle
# The knowledge graph contains 780753 nodes and 7787310 edges

# %% [markdown]
# #### Load Node Metadata

# %%
# read in node metadata
# data_loc = write_location + data_urls[1].split('/')[-1]
data_loc = 'data/PheKnowLator_v3.0.2_full_subclass_inverseRelations_OWLNETS_NodeLabels.txt'
node_data = pd.read_csv(data_loc, header=0, sep=r"\t", encoding="utf8", engine='python', quoting=3)
node_data['entity_uri'] = node_data['entity_uri'].str.strip('<>')  # remove angle brackets
node_data.head()
# Out:
#   entity_type  integer_id                                         entity_uri  \
# 0       NODES      684158       https://www.ncbi.nlm.nih.gov/snp/rs864622148
# 1       NODES      668197  https://uswest.ensembl.org/Homo_sapiens/Transc...
# 2       NODES      769680        http://purl.obolibrary.org/obo/CHEBI_116891
# 3       NODES      381659        https://www.ncbi.nlm.nih.gov/snp/rs61741688
# 4       NODES      720533         http://purl.obolibrary.org/obo/PR_Q9Y2I7-3
#
#                                                label  \
# 0          NM_000051.4(ATM):c.5887G>A (p.Asp1963Asn)
# 1                                           CUL9-211
# 2  3-(3-methylphenyl)-2-sulfanylidene-1H-benzofur...
# 3          NM_001272071.2(AP1S2):c.288T>C (p.Ser96=)
# 4  1-phosphatidylinositol 3-phosphate 5-kinase is...
#
#                               description/definition          synonym
# 0  This variant is a germline single nucleotide v...              NaN
# 1  Transcript CUL9-211 is classified as type 'non...              NaN
# 2                                                NaN              NaN
# 3  This variant is a germline single nucleotide v...              NaN
# 4  A 1-phosphatidylinositol 3-phosphate 5-kinase ...  hPIKFYVE/iso:h3

# %%
# convert node data to dictionary
node_data_dict = dict()
for idx, row in tqdm(node_data.iterrows(), total=node_data.shape[0]):
    node_data_dict[row['entity_uri']] = {
        'label': row['label'],
        'description': row['description/definition']
    }
# Out:
#   0%|          | 0/781049 [00:00<?, ?it/s]

# %% [markdown]
# <br>
#
# ***
# ***
#
# # Prerequisites

# %% [markdown]
# <br>
#
# ***
#
# ## OMOP2OBO Mappings <a class="anchor" id="omop2obo-mappings"></a> <img width="225" align="right" src="https://user-images.githubusercontent.com/8030363/195580079-06726eac-38e8-44c9-8de6-32179bca9614.png">
# ***
# ____
#
#
# **GitHub:** https://github.com/callahantiff/OMOP2OBO
# **Dashboard:**  http://tiffanycallahan.com/OMOP2OBO_Dashboard/
# **Zenodo Mapping Archive:** [Condition Occurrence](https://zenodo.org/record/6949688); [Drug Exposure Ingredients](https://zenodo.org/record/6949696); [Measurement](https://zenodo.org/record/6949858)
#
# <br>
#
# <a target="_blank" href="https://user-images.githubusercontent.com/8030363/195500004-0e20019c-f33b-40a6-b3be-739b1136021a.png"> <img src="https://user-images.githubusercontent.com/8030363/195500004-0e20019c-f33b-40a6-b3be-739b1136021a.png" width="600"></a>
#
# <br>
#
# This tutorial depends on mappings from the [`OMOP2OBO`](https://github.com/callahantiff/OMOP2OBO/wiki) in order to align concepts in the [OMOP (Observational Medical Outcomes Partnership) Common Data Model](https://ohdsi.github.io/CommonDataModel/cdm60.html#NOTE_ABOUT_CDM_v60). An example of the mappings is shown in the figure above. As shown in this figure, mappings were created to eight Open Biological and Biomedical Ontology (OBO) Foundry ontologies spanning diseases (Mondo Disease Ontology [`Mondo`]), phenotypes (Human Phenotype Ontology [`HPO`]), anatomical entities (Uber Anatomy Ontology [`Uberon`]; Cell Ontology [`CL`]), organisms (National Center for Biotechnology Information Taxon Ontology [`NCBITaxon`]), chemicals (Chemical Entities of Biological Interest [`ChEBI`]), vaccines (the Vaccine Ontology [`VO`]), and proteins (the Protein Ontology [`PRO`]).
#
# A script ([`process_omop2obo_mappings.py`](https://github.com/callahantiff/PheKnowLator/tree/master/notebooks/tutorials/entity_search/process_omop2obo_mappings.py)) has been developed to download the latest OMOP2OBO mappings for the OMOP [Condition Occurrence](https://ohdsi.github.io/CommonDataModel/cdm60.html#CONDITION_OCCURRENCE) and [Drug Exposure ingredients](https://ohdsi.github.io/CommonDataModel/cdm60.html#DRUG_EXPOSURE) tables (please verify this when running this Notebook using the links provided above). Once downloaded, the mappings are converted to a dictionary and pickled to a file called `notebooks/tutorials/entity_search/data/omop2obo_mapping_dict.pkl`. The code chunk below runs this script and reads in the resulting dictionary.
#
# **Mapping Example:**
# The following example demonstrates how to use the mapping dictionary. In this example, the `OMOP` concept [`256439`](https://athena.ohdsi.org/search-terms/terms/256439) is searched and returns mappings to both `Mondo` and `HPO`.
#
# The structure of the dictionary is shown below:
#
# ```python
# omop2obo_mappings[256439]
#
# {
#     'concept_name': 'Allergic rhinitis due to pollen',
#     'mapping(s)': {
#         'HP': {
#             'mapping_logic': 'OR',
#             'id': 'HP_0012395 | HP_0003193',
#             'label': 'seasonal allergy | allergic rhinitis'
#         },
#         'MONDO': {
#             'mapping_logic': nan,
#             'id': 'MONDO_0011786',
#             'label': 'allergic rhinitis'
#         }
#     }
# }
# ```
#
# <br>

# %%
# run script to download and process OMOP2OBO mappings
# %run process_omop2obo_mappings.py

# %%
# load the mapping dictionary
omop2obo_mappings = pickle.load(open(write_location + 'omop2obo_mapping_dict.pkl', 'rb'))

# %% [markdown]
# <br>
#
# ***
#
# ## PheKnowLator Knowledge Graph Schema <a class="anchor" id="pkt-schema"></a>
# ***
# ____
#
# The interactive figures below (go ahead, try hovering over the nodes and edges, it's awesome ) provide a high-level overview of the current (`v3.0.2`) PheKnowLator knowledge graph schema (i.e., the primary node types and relationships). Note that there are two figures shown below.
# 1. The first figure illustrates the relationships between the core set of 12 OBO Foundry ontologies when including their imported ontologies.
# 2. The second figure Illustrates the edges that are added to the core set of merged ontologies.
#
# Shared colors between the figures represent a shared resource. For example, chemicals, cofactors, and catalysts share the same color (maroon) and are part of ChEBI. This is the same for the RO, which is represented in the first figure as the black lines between nodes. The green and yellow rectangles indicate data sources that are not from an OBO Foundry ontology and the specific ontology used to integrate them with the core set of ontologies in the first figure. For example, variant, transcript, and gene data are connected to the core ontology set via the SO.
#
# Acronyms: `CL` (Cell ontology); `CLO` (Cell Line Ontology); `ChEBI` (Chemical Entities of Biological Interest); `GO` (Gene Ontology); `HPO` (Human Phenotype Ontology); `Mondo` (Mondo Disease Ontology); `PRO` (Protein Ontology); `PW` (Pathway Ontology); `SO` (Sequence Ontology); `VO` (Vaccine Ontology); `Uberon` (Uber-Anatomy Ontology).
#
#
# For more information please see the associated Wiki page (https://github.com/callahantiff/PheKnowLator/wiki).

# %%
# visualize the core set of OBOs used in phenknowlator knowledge graphs
g = visualize_pheknowlator_ontologies()
g.force_atlas_2based(gravity=-25, central_gravity=0.001, spring_length=90, spring_strength=0.08, damping=2, overlap=3)   
g.toggle_physics(True)
g.show('PheKnowLator_OBOs.html')

# %%
# visualize edges added to the core set of OBO ontologies
g = visualize_pheknowlator_schema()
g.force_atlas_2based(gravity=-25, central_gravity=0.001, spring_length=90, spring_strength=0.08, damping=2, overlap=3)   
g.toggle_physics(True)
g.show('PheKnowLator_Schema.html')

# %% [markdown]
# <br>
#
# ***
# ***
#
# # Drug Safety Task - Knowledge Graph-based Drug Safety
#
# <br>

# %% [markdown]
# <br>
#
# ***
#
# ## Knowledge-based Characterization  <a class="anchor" id="kg-characterization"></a>
# ***
# ____
#
# The goal is to use the knowledge graph to explore what we know about specific concepts as well as what we can say about pairs of concepts. Additional details are presented by comparison below:
#
# #### [Node-Level](#node-level)
#  - <u>Node Ancestry</u>: Identify all ancestors for each node up to the root.
#  - <u>Node Neighborhood</u>: Returns all nodes reachable from a node of interest via a single directed edge.
#
#
# #### [Path-Level](#path-level)
#   - <u>Shortest Path</u>: Returns the single shortest path.
#   - <u>Simple Paths</u>: Returns all paths with no repeated nodes of varying length.
#   - <u>Efficiency</u>: A measure of how efficiently information is exchanged between nodes, ranging from 0-1, where 1 indicates high efficiency.
#
# ---

# %% [markdown]
# ### Look-up PheKnowLator Entities
# use the `OMOP2OBO` mapping dictionary to obtain PheKnowLator entities for the following `OMOP` concepts:
# - lisinopril [`1308216`](https://athena.ohdsi.org/search-terms/terms/1308216)
# - ivermectin [`1784444`](https://athena.ohdsi.org/search-terms/terms/1784444)
# - Myocardial Infarction [`4329847`](https://athena.ohdsi.org/search-terms/terms/4329847)
# - Contact Dermatitis [`134438`](https://athena.ohdsi.org/search-terms/terms/134438)
# - Ingrowing Toenail [`4290993`](https://athena.ohdsi.org/search-terms/terms/4290993)
# - Presbyopia [`373478`](https://athena.ohdsi.org/search-terms/terms/373478)
# - neurotoxicity [`4024301`](https://athena.ohdsi.org/search-terms/terms/4024301)
#
# <br>
#
# #### 💡 Concept Search
# - [Athena](https://athena.ohdsi.org/) is a great tool to use when looking looking for the OMOP concepts
# - [Ontology Lookup Service](https://www.ebi.ac.uk/ols/) is a very useful tool for
#
# <br>

# %%
# lisinopril
omop2obo_mappings[1308216]

# %%
# ivermectin
omop2obo_mappings[1784444]

# %%
# myocardial infarction
omop2obo_mappings[4329847]

# %%
# contact dermatits
omop2obo_mappings[134438]

# %%
# ingrowing toenails
omop2obo_mappings[4290993]

# %%
# presbyopia
omop2obo_mappings[373478]

# %%
# neurotoxicity
omop2obo_mappings[4024301]

# %% [markdown]
# <br>
#
# ### Node-Level  <a class="anchor" id="node-level"></a>
# ***
#
# #### Nodes
# - **Drugs**
#   - [lisinopril (`CHEBI_6503`)](#chebi_6503)
#   - [ivermectin (`CHEBI_6078`)](#chebi_6078)
# - **Outcomes (diseases)**
#   - [myocardial infarction (`MONDO_0005068`)](#mondo_0005068)
#   - [contact dermatitis (`MONDO_0005480`)](#mondo_0005480)
#   - [ingrowing toenail (`HP_0012710`)](#hp_0012710)
#   - [presbyopia (`MONDO_0001330`)](#mondo_0001330)
#   - [neurotoxicity (`MONDO_0005527`)](#mondo_0005527)

# %% [markdown]
# ***
#
# #### lisinopril (`CHEBI_6503`) <a class="anchor" id="chebi_6503"></a>

# %%
node = [obo.CHEBI_6503]
degree = str(kg.degree(node[0]))
in_edges = str(len(kg.in_edges(node[0])))
out_edges = str(len(kg.out_edges(node[0])))
print('This node has degree {}, which consists of {} in-edges and {} out-edges'.format(degree, in_edges, out_edges))
# Out:
# This node has degree 351, which consists of 174 in-edges and 177 out-edges

# %% [markdown]
# *Ancestors*

# %%
# examine the node's ancestors
prefix = 'CHEBI'
chebi6503_anc_dict = processes_ancestor_path_list(nx_ancestor_search(kg, node.copy(), prefix))
chebi6503_ancestors = format_path_ancestors(chebi6503_anc_dict, node_data_dict)

# %%
# visualize hierarchy
# visualize_ancestor_tree(chebi6503_ancestors)  # using static viz
g = visualize_kg_output(kg, chebi6503_ancestors, node_data_dict)
g.force_atlas_2based(gravity=-25, central_gravity=0.001, spring_length=90, spring_strength=0.08, damping=2, overlap=0)   
g.toggle_physics(True)
g.show('{}_Ancestor_Graph.html'.format(str(node[0]).split('/')[-1]))

# %%
# print results -- nodes are ordered by seniority (higher numbers indicate closer to root)
print('Ancestors of {}'.format(node[0]))
if node_data_dict[str(node[0])]['description'] != 'None': print('- Definition: {}\n'.format(node_data_dict[str(node[0])]['description']))
for level in range(len(chebi6503_ancestors)):
    print('Level: {}'.format(str(level)))
    for v in chebi6503_ancestors[::-1][level]:
        v_uri = URIRef(v.split('(')[-1].strip(')'))
        descs = len([a[1] for b in [[[i, n[0]] for j in [kg.get_edge_data(*(n[0], v_uri)).keys()]
                                     for i in j] for n in list(kg.in_edges(v_uri))] for a in b
                     if a[0] == RDFS.subClassOf])
        uri_strip = re.sub('http://purl.obolibrary.org/obo/', '', v)
        print('- {}'.format(uri_strip))
        print('- Definition: {}'.format(node_data_dict[str(v_uri)]['description']))
        print('- Descendants: {}\n'.format(descs + 1))
# Out:
# Ancestors of http://purl.obolibrary.org/obo/CHEBI_6503
# - Definition: nan
#
# Level: 0
# - chemical entity (CHEBI_24431)
# - Definition: A chemical entity is a physical entity of interest in chemistry including molecular entities, parts thereof, and chemical substances.
# - Descendants: 14
#
# Level: 1
# - molecular entity (CHEBI_23367)
# - Definition: Any constitutionally or isotopically distinct atom, molecule, ion, ion pair, radical, radical ion, complex, conformer etc., identifiable as a separately distinguishable entity.
# - Descendants: 40
#
# Level: 2
# - polyatomic entity (CHEBI_36357)
# - Definition: Any molecular entity consisting of more than one atom.
# - Descendants: 8
#
# Level: 3
# - heteroatomic molecular entity (CHEBI_37577)
# - Definition: A molecular entity consisting of two or more chemical elements.
# - Descendants: 10
#
# Level: 4
# - addition compound (CHEBI_35504)
# - Definition: An addition compound contains two or more simpler compounds that can be packed in a definite ratio into a crystal. The term covers donor-acceptor complexes (adducts) and a variety of lattice compounds.
# - Descendants: 7
#
# Level: 5
# - hydrate (CHEBI_35505)
# - Definition: An addition compound that contains water in weak chemical combination with another compound.
# - Descendants: 204

# %% [markdown]
# *Neighborhood*

# %%
# examine the node's neigborhood (out-edges)
nodes = list(kg.neighbors(node[0]))
neighbors = [a for b in [[[i, n] for j in [kg.get_edge_data(*(node[0], n)).keys()]
                          for i in j] for n in nodes] for a in b]
chebi6503_sorted_neigbors = sorted(neighbors, key=lambda x: (str(x[1]).split('/')[-1], x[0]))

print('{} has {} neighbors'.format(str(node[0]).split('/')[-1], degree))
# Out:
# CHEBI_6503 has 351 neighbors

# %%
# print node's neigborhood (out-edges)
formats_node_information(node, chebi6503_sorted_neigbors, node_data_dict, verbose=False)
# Out:
# >>> lisinopril dihydrate (CHEBI_6503) - subClassOf - hydrate (CHEBI_35505)
# >>> lisinopril dihydrate (CHEBI_6503) - has_role - antihypertensive agent (CHEBI_35674)
# >>> lisinopril dihydrate (CHEBI_6503) - has part - lisinopril (CHEBI_43755)
# >>> lisinopril dihydrate (CHEBI_6503) - causally related to -

# >>> lisinopril dihydrate (CHEBI_6503) - causally related to - vasculitis (MONDO_0018882)
# >>> lisinopril dihydrate (CHEBI_6503) - causally related to - Lyell syndrome (MONDO_0018890)
# >>> lisinopril dihydrate (CHEBI_6503) - causally related to - intrahepatic cholestasis (MONDO_0019072)
# >>> lisinopril dihydrate (CHEBI_6503) - causally related to - immunoglobulin a vasculitis (MONDO_0019167)
# >>> lisinopril dihydrate (CHEBI_6503) - causally related to - cutaneous leukocytoclastic angiitis (MONDO_0019509)
# >>> lisinopril dihydrate (CHEBI_6503) - causally related to - acquired angioedema (MONDO_0019624)
# >>> lisinopril dihydrate (CHEBI_6503) - causally related to - glomerular disease (MONDO_0019722)
# >>> lisinopril dihydrate (CHEBI_6503) - causally related to - toxic epidermal necrolysis (MONDO_0019810)
# >>> lisinopril dihydrate (CHEBI_6503) - causally related to - hyperlipidemia (MONDO_0021187)
# >>> lisinopril dihydrate (CHEBI_6503) - causally related to - acquired lactic acidosis (MONDO_0024306)
# >>> lisinopril dihydrate (CHEBI_6503) - causally related to - chronic renal failure syndrome (MONDO_0024327)
# >>> lisinopril dihydrate (CHEBI_6503) - causally related to - manic bipolar affective disorder (MONDO_0024612)
# >>> lisinopril dihydrate (CHEBI_6503) - causally related to - bipolar depression (MONDO_0024613)
# >>> lisinopril dihydrate (CHEBI_6503) - causally related to - erythema multiforme major (MONDO_0044719)
# >>> lisinopril dihydrate (CHEBI_6503) - causally related to - sleep disorder (MONDO_0100081)
# >>> lisinopril dihydrate (CHEBI_6503) - interacts with - renin isoform b (human) (PR_000050224)
# >>> lisinopril dihydrate (CHEBI_6503) - interacts with - renin (human) (PR_P00797)
# >>> lisinopril dihydrate (CHEBI_6503) - interacts with - angiotensinogen (human) (PR_P01019)
# >>> lisinopril dihydrate (CHEBI_6503) - interacts with - natriuretic peptides A (human) (PR_P01160)
# >>> lisinopril dihydrate (CHEBI_6503) - interacts with - endothelin-1 (human) (PR_P05305)
# >>> lisinopril dihydrate (CHEBI_6503) - interacts with - insulin-like growth factor-binding protein 1 (human) (PR_P08833)
# >>> lisinopril dihydrate (CHEBI_6503) - interacts with - angiotensin-converting enzyme (human) (PR_P12821)

# %% [markdown]
# ***
#
# #### ivermectin (`CHEBI_6078`) <a class="anchor" id="chebi_6078"></a>

# %%
node = [obo.CHEBI_6078]
degree = str(kg.degree(node[0]))
in_edges = str(len(kg.in_edges(node[0])))
out_edges = str(len(kg.out_edges(node[0])))
print('This node has degree {}, which consists of {} in-edges and {} out-edges'.format(degree, in_edges, out_edges))
# Out:
# This node has degree 9900, which consists of 4946 in-edges and 4954 out-edges

# %% [markdown]
# *Ancestors*

# %%
# examine the node's ancestors
prefix = 'CHEBI'
chebi6078_anc_dict = processes_ancestor_path_list(nx_ancestor_search(kg, node.copy(), prefix))
chebi6078_ancestors = format_path_ancestors(chebi6078_anc_dict, node_data_dict)

# %%
# visualize hierarchy
# visualize_ancestor_tree(chebi6078_ancestors)  # using static viz
g = visualize_kg_output(kg, chebi6078_ancestors, node_data_dict)
g.force_atlas_2based(gravity=-25, central_gravity=0.001, spring_length=90, spring_strength=0.08, damping=2, overlap=0)   
g.toggle_physics(True)
g.show('{}_Ancestor_Graph.html'.format(str(node[0]).split('/')[-1]))
# Out:
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# CHEBI_6078_Ancestor_Graph.html
#         <iframe
#             width="100%"
#             height="750px"
#             src="CHEBI_6078_Ancestor_Graph.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# print results -- nodes are ordered by seniority (higher numbers indicate closer to root)
print('Ancestors of {}'.format(node[0]))
if node_data_dict[str(node[0])]['description'] != 'None': print('- Definition: {}\n'.format(node_data_dict[str(node[0])]['description']))
for level in range(len(chebi6078_ancestors)):
    print('Level: {}'.format(str(level)))
    for v in chebi6078_ancestors[::-1][level]:
        v_uri = URIRef(v.split('(')[-1].strip(')'))
        descs = len([a[1] for b in [[[i, n[0]] for j in [kg.get_edge_data(*(n[0], v_uri)).keys()]
                                     for i in j] for n in list(kg.in_edges(v_uri))] for a in b
                     if a[0] == RDFS.subClassOf])
        uri_strip = re.sub('http://purl.obolibrary.org/obo/', '', v)
        print('- {}'.format(uri_strip))
        print('- Definition: {}'.format(node_data_dict[str(v_uri)]['description']))
        print('- Descendants: {}\n'.format(descs + 1))
# Out:
# Ancestors of http://purl.obolibrary.org/obo/CHEBI_6078
# - Definition: A mixture consisting of >= 90% 22,23-dihydroavermectin B1a (R = Me) and <= 10% 22,23-dihydroavermectin B1b (R = H). A semi-synthetic derivative of abamectin, it is used as a broad-spectrum antiparasite medication, particularly against worms (except tapeworms), although it is also effective against most mites and some lice.
#
# Level: 0
# - chemical entity (CHEBI_24431)
# - Definition: A chemical entity is a physical entity of interest in chemistry including molecular entities, parts thereof, and chemical substances.
# - Descendants: 14
#
# Level: 1
# - chemical substance (CHEBI_59999)
# - Definition: A chemical substance is a portion of matter of constant composition, composed of molecular entities of the same type or of different types.
# - Descendants: 6
#
# Level: 2
# - mixture (CHEBI_60004)
# - Definition: A mixture is a chemical substance composed of multiple molecules, at least two of which are of a different kind.
# - Descendants: 128

# %% [markdown]
# *Neighborhood*

# %%
# examine the node's neigborhood (out-edges)
nodes = list(kg.neighbors(node[0]))
neighbors = [a for b in [[[i, n] for j in [kg.get_edge_data(*(node[0], n)).keys()]
                          for i in j] for n in nodes] for a in b]
chebi6078_sorted_neigbors = sorted(neighbors, key=lambda x: (str(x[1]).split('/')[-1], x[0]))

print('{} has {} neighbors'.format(str(node[0]).split('/')[-1], degree))
# Out:
# CHEBI_6078 has 9900 neighbors

# %%
# print node's neigborhood (out-edges)
formats_node_information(node, chebi6078_sorted_neigbors, node_data_dict, verbose=False)
# Out:
# >>> ivermectin (CHEBI_6078) - has_role - insecticide (CHEBI_24852)
# >>> ivermectin (CHEBI_6078) - has_role - anthelminthic drug (CHEBI_35443)
# >>> ivermectin (CHEBI_6078) - has_role - antinematodal drug (CHEBI_35444)
# >>> ivermectin (CHEBI_6078) - has_role - antiprotozoal drug (CHEBI_35820)
# >>> ivermectin (CHEBI_6078) - subClassOf - mixture (CHEBI_60004)
# >>> ivermectin (CHEBI_6078) - has part - 22,23-dihydroavermectin B1a (CHEBI_63941)
# >>> ivermectin (CHEBI_6078) - has part - 22,23-dihydroavermectin B1b (CHEBI_63943)
# >>> ivermectin (CHEBI_6078) - has_role - scabicide (CHEBI_73333)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - nucleotide binding (GO_0000166)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - microtubule cytoskeleton organization (GO_0000226)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - mitotic cell cycle (GO_0000278)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - lytic vacuole (GO_0000323)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - RNA splicing, via transesterification reactions (GO_0000375)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - RNA splicing, via transesterification reactions with bulged adenosine as nucleophile (GO_0000377)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - mRNA splicing, via spliceosome (GO_0000398)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - cell morphogenesis (GO_0000902)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - nucleoside binding (GO_0001882)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - purine nucleoside binding (GO_0001883)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - regulation of protein phosphorylation (GO_0001932)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - cytoplasmic translation (GO_0002181)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - immune system process (GO_0002376)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - regulation of immune system process (GO_0002682)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - nucleic acid binding (GO_0003676)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - RNA binding (GO_0003723)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - structural constituent of ribosome (GO_0003735)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - actin binding (GO_0003779)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - catalytic activity (GO_0003824)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - signaling receptor binding (GO_0005102)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - structural molecule activity (GO_0005198)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - binding (GO_0005488)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - protein binding (GO_0005515)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - ATP binding (GO_0005524)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - GTP binding (GO_0005525)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - intracellular anatomical structure (GO_0005622)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - cell (GO_0005623)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - nucleus (GO_0005634)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - nuclear envelope (GO_0005635)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - nucleoplasm (GO_0005654)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - spliceosomal complex (GO_0005681)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - chromosome (GO_0005694)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - nucleolus (GO_0005730)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - cytoplasm (GO_0005737)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - mitochondrion (GO_0005739)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - mitochondrial envelope (GO_0005740)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - mitochondrial inner membrane (GO_0005743)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - mitochondrial matrix (GO_0005759)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - lysosome (GO_0005764)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - endosome (GO_0005768)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - early endosome (GO_0005769)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - vacuole (GO_0005773)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - endoplasmic reticulum (GO_0005783)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - endoplasmic reticulum membrane (GO_0005789)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - Golgi apparatus (GO_0005794)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - microtubule organizing center (GO_0005815)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - spindle (GO_0005819)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - cytosol (GO_0005829)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - ribosome (GO_0005840)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - cytoskeleton (GO_0005856)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - plasma membrane (GO_0005886)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - cell cortex (GO_0005938)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - carbohydrate metabolic process (GO_0005975)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - organic acid metabolic process (GO_0006082)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - generation of precursor metabolites and energy (GO_0006091)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - nucleobase-containing compound metabolic process (GO_0006139)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - purine nucleotide metabolic process (GO_0006163)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - purine nucleotide biosynthetic process (GO_0006164)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - DNA metabolic process (GO_0006259)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - chromatin organization (GO_0006325)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - transcription, DNA-templated (GO_0006351)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - regulation of transcription, DNA-templated (GO_0006355)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - regulation of transcription by RNA polymerase II (GO_0006357)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - rRNA processing (GO_0006364)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - transcription by RNA polymerase II (GO_0006366)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - RNA processing (GO_0006396)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - mRNA processing (GO_0006397)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - RNA catabolic process (GO_0006401)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - mRNA catabolic process (GO_0006402)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - RNA localization (GO_0006403)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - translation (GO_0006412)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - regulation of translation (GO_0006417)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - protein folding (GO_0006457)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - cellular protein modification process (GO_0006464)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - protein phosphorylation (GO_0006468)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - proteolysis (GO_0006508)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - ubiquitin-dependent protein catabolic process (GO_0006511)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - peptide metabolic process (GO_0006518)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - cellular amino acid metabolic process (GO_0006520)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - lipid metabolic process (GO_0006629)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - cellular aromatic compound metabolic process (GO_0006725)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - nucleoside phosphate metabolic process (GO_0006753)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - phosphorus metabolic process (GO_0006793)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - phosphate-containing compound metabolic process (GO_0006796)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - nitrogen compound metabolic process (GO_0006807)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - transport (GO_0006810)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - ion transport (GO_0006811)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - intracellular protein transport (GO_0006886)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - endocytosis (GO_0006897)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - nucleocytoplasmic transport (GO_0006913)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - autophagy (GO_0006914)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - apoptotic process (GO_0006915)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - movement of cell or subcellular component (GO_0006928)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - response to stress (GO_0006950)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - defense response (GO_0006952)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - cellular response to DNA damage stimulus (GO_0006974)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - response to oxidative stress (GO_0006979)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - organelle organization (GO_0006996)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - mitochondrion organization (GO_0007005)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - cytoskeleton organization (GO_0007010)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - actin filament organization (GO_0007015)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - microtubule-based process (GO_0007017)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with -

# >>> ivermectin (CHEBI_6078) - molecularly interacts with - actin cytoskeleton (GO_0015629)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - microtubule cytoskeleton (GO_0015630)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - peptide transport (GO_0015833)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - nucleobase-containing compound transport (GO_0015931)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - energy derivation by oxidation of organic compounds (GO_0015980)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - membrane (GO_0016020)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - viral process (GO_0016032)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - cellular component organization (GO_0016043)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - vesicle organization (GO_0016050)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - organic acid biosynthetic process (GO_0016053)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - RNA metabolic process (GO_0016070)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - mRNA metabolic process (GO_0016071)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - rRNA metabolic process (GO_0016072)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - vesicle-mediated transport (GO_0016192)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - macroautophagy (GO_0016236)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - phosphorylation (GO_0016310)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - pyrophosphatase activity (GO_0016462)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - cell migration (GO_0016477)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - oxidoreductase activity (GO_0016491)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - nuclear body (GO_0016604)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - nuclear speck (GO_0016607)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - transferase activity (GO_0016740)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - transferase activity, transferring phosphorus-containing groups (GO_0016772)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - hydrolase activity (GO_0016787)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - hydrolase activity, acting on acid anhydrides (GO_0016817)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - hydrolase activity, acting on acid anhydrides, in phosphorus-containing anhydrides (GO_0016818)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - ATP hydrolysis activity (GO_0016887)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - purine nucleotide binding (GO_0017076)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - nucleoside-triphosphatase activity (GO_0017111)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - drug metabolic process (GO_0017144)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - heterocycle biosynthetic process (GO_0018130)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - peptidyl-amino acid modification (GO_0018193)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - guanyl nucleotide binding (GO_0019001)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - viral life cycle (GO_0019058)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - regulation of nucleobase-containing compound metabolic process (GO_0019219)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - regulation of phosphate metabolic process (GO_0019220)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - regulation of metabolic process (GO_0019222)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - aromatic compound biosynthetic process (GO_0019438)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - aromatic compound catabolic process (GO_0019439)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - protein metabolic process (GO_0019538)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - organophosphate metabolic process (GO_0019637)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - ribose phosphate metabolic process (GO_0019693)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - carboxylic acid metabolic process (GO_0019752)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - organelle inner membrane (GO_0019866)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - enzyme binding (GO_0019899)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - kinase binding (GO_0019900)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - protein kinase binding (GO_0019901)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - protein domain specific binding (GO_0019904)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - modification-dependent protein catabolic process (GO_0019941)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - neurogenesis (GO_0022008)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - cell cycle process (GO_0022402)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - cellular component disassembly (GO_0022411)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - cellular component assembly (GO_0022607)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - biological adhesion (GO_0022610)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - ribonucleoprotein complex biogenesis (GO_0022613)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - ribonucleoprotein complex assembly (GO_0022618)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - cytosolic ribosome (GO_0022626)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - regulation of signaling (GO_0023051)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - signaling (GO_0023052)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - positive regulation of signaling (GO_0023056)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - negative regulation of signaling (GO_0023057)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - actin filament-based process (GO_0030029)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - cell projection organization (GO_0030030)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - actin cytoskeleton organization (GO_0030036)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - cell junction (GO_0030054)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - transport vesicle (GO_0030133)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - coated vesicle (GO_0030135)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - secretory granule (GO_0030141)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - cell differentiation (GO_0030154)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - regulation of proteolysis (GO_0030162)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - protein catabolic process (GO_0030163)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - neuron differentiation (GO_0030182)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - enzyme regulator activity (GO_0030234)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - axon (GO_0030424)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - dendrite (GO_0030425)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - midbody (GO_0030496)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - adenyl nucleotide binding (GO_0030554)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - cytoplasmic vesicle membrane (GO_0030659)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - organelle membrane (GO_0031090)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - neuron projection development (GO_0031175)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - cell leading edge (GO_0031252)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - regulation of cellular metabolic process (GO_0031323)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - negative regulation of cellular metabolic process (GO_0031324)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - positive regulation

# >>> ivermectin (CHEBI_6078) - molecularly interacts with - peptide biosynthetic process (GO_0043043)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - positive regulation of apoptotic process (GO_0043065)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - negative regulation of apoptotic process (GO_0043066)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - regulation of programmed cell death (GO_0043067)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - positive regulation of programmed cell death (GO_0043068)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - negative regulation of programmed cell death (GO_0043069)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - positive regulation of catalytic activity (GO_0043085)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - negative regulation of catalytic activity (GO_0043086)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - ion binding (GO_0043167)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - anion binding (GO_0043168)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - cation binding (GO_0043169)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - macromolecule metabolic process (GO_0043170)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - organelle (GO_0043226)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - membrane-bounded organelle (GO_0043227)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - non-membrane-bounded organelle (GO_0043228)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - intracellular organelle (GO_0043229)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - intracellular membrane-bounded organelle (GO_0043231)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - intracellular non-membrane-bounded organelle (GO_0043232)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - organelle lumen (GO_0043233)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - regulation of protein-containing complex assembly (GO_0043254)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - macromolecule modification (GO_0043412)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - oxoacid metabolic process (GO_0043436)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - regulation of kinase activity (GO_0043549)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - cellular amide metabolic process (GO_0043603)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - amide biosynthetic process (GO_0043604)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - modification-dependent macromolecule catabolic process (GO_0043632)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - macromolecular complex subunit organization (GO_0043933)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - cellular component biogenesis (GO_0044085)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - regulation of cellular component biogenesis (GO_0044087)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - positive regulation of cellular component biogenesis (GO_0044089)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - negative regulation of molecular function (GO_0044092)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - positive regulation of molecular function (GO_0044093)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - cellular metabolic process (GO_0044237)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - primary metabolic process (GO_0044238)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - cellular catabolic process (GO_0044248)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - cellular biosynthetic process (GO_0044249)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - cellular lipid metabolic process (GO_0044255)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - cellular protein catabolic process (GO_0044257)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - cellular macromolecule metabolic process (GO_0044260)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - cellular macromolecule catabolic process (GO_0044265)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - cellular protein metabolic process (GO_0044267)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - cellular nitrogen compound catabolic process (GO_0044270)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - cellular nitrogen compound biosynthetic process (GO_0044271)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - small molecule metabolic process (GO_0044281)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - small molecule biosynthetic process (GO_0044283)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - cell body (GO_0044297)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - ubiquitin-like protein ligase binding (GO_0044389)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - ribosomal subunit (GO_0044391)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - biological process involved in symbiotic interaction (GO_0044403)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - biological process involved in interspecies interaction between organisms (GO_0044419)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - organelle part (GO_0044422)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - intracellular part (GO_0044424)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - membrane part (GO_0044425)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - chromosomal part (GO_0044427)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - nuclear part (GO_0044428)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - cytoplasmic part (GO_0044444)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - intracellular organelle part (GO_0044446)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - synapse part (GO_0044456)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - plasma membrane part (GO_0044459)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - cell part (GO_0044464)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - protein-containing complex binding (GO_0044877)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - establishment of protein localization (GO_0045184)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - synapse (GO_0045202)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - regulation of cell differentiation (GO_0045595)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - negative regulation of nucleobase-containing compound metabolic process (GO_0045934)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - positive regulation of nucleobase-containing compound metabolic process (GO_0045935)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - negative regulation of phosphate metabolic process (GO_0045936)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - positive regulation of phosphate metabolic process (GO_0045937)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - ATP metabolic process (GO_0046034)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - ribose phosphate biosynthetic process (GO_0046390)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - carboxylic acid biosynthetic process (GO_0046394)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - heterocycle metabolic process (GO_0046483)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - heterocycle catabolic process (GO_0046700)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - metal ion binding (GO_0046872)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - secretion (GO_0046903)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - intracellular transport (GO_0046907)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - protein dimerization activity (GO_0046983)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - Golgi vesicle transport (GO_0048193)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - organelle fission (GO_0048285)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - cell development (GO_0048468)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - perinuclear region of cytoplasm (GO_0048471)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - animal organ development (GO_0048513)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - positive regulation of biological process (GO_0048518)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - negative regulation of biological process (GO_0048519)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - positive regulation of cellular process (GO_0048522)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - negative regulation of cellular process (GO_0048523)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - regulation of response to stimulus (GO_0048583)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - positive regulation of response to stimulus (GO_0048584)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - negative regulation of response to stimulus (GO_0048585)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - neuron development (GO_0048666)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - generation of neurons (GO_0048699)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - system development (GO_0048731)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - anatomical structure development (GO_0048856)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - cellular developmental process (GO_0048869)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - cell motility (GO_0048870)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - chemical homeostasis (GO_0048878)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - nucleic acid transport (GO_0050657)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - RNA transport (GO_0050658)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - regulation of biological process (GO_0050789)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - regulation of catalytic activity (GO_0050790)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - regulation of developmental process (GO_0050793)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - regulation of cellular process (GO_0050794)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - response to stimulus (GO_0050896)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - GTPase binding (GO_0051020)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - regulation of transport (GO_0051049)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - positive regulation of transport (GO_0051050)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - positive regulation of developmental process (GO_0051094)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - regulation of cellular component organization (GO_0051128)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - negative regulation of cellular component organization (GO_0051129)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - positive regulation of cellular component organization (GO_0051130)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - nuclear transport (GO_0051169)
# >>> ivermectin (CHEBI_6078) - molecularly interacts with - regulation of nitrogen compound metabolic process (GO_0051171)
# ...
# >>> ivermectin (CHEBI_6078) - interacts with - 28S ribosomal protein S17, mitochondrial (human) (PR_Q9Y2R5)
# >>> ivermectin (CHEBI_6078) - interacts with - 28S ribosomal protein S7, mitochondrial (human) (PR_Q9Y2R9)
# >>> ivermectin (CHEBI_6078) - interacts with - lambda-crystallin homolog (human) (PR_Q9Y2S2)
# >>> ivermectin (CHEBI_6078) - interacts with - translation machinery-associated protein 7 (human) (PR_Q9Y2S6)
# >>> ivermectin (CHEBI_6078) - interacts with - polymerase delta-interacting protein 2 (human) (PR_Q9Y2S7)
# >>> ivermectin (CHEBI_6078) - interacts with - AP-3 complex subunit mu-1 (human) (PR_Q9Y2T2)
# >>> ivermectin (CHEBI_6078) - interacts with - guanine deaminase (human) (PR_Q9Y2T3)
# >>> ivermectin (CHEBI_6078) - interacts with - inner nuclear membrane protein Man1 (human) (PR_Q9Y2U8)
# >>> ivermectin (CHEBI_6078) - interacts with - calcium-regulated heat-stable protein 1 (human) (PR_Q9Y2V2)
# >>> ivermectin (CHEBI_6078) - interacts with - thyroid hormone receptor-associated protein 3 (human) (PR_Q9Y2W1)
# >>> ivermectin (CHEBI_6078) - interacts with - WW domain-binding protein 11 (human) (PR_Q9Y2W2)
# >>> ivermectin (CHEBI_6078) - interacts with - tudor and KH domain-containing protein (human) (PR_Q9Y2W6)
# >>> ivermectin (CHEBI_6078) - interacts with - mediator of RNA polymerase II transcription subunit 16 (human) (PR_Q9Y2X0)
# >>> ivermectin (CHEBI_6078) - interacts with - nucleolar protein 58 (human) (PR_Q9Y2X3)
# >>> ivermectin (CHEBI_6078) - interacts with - ARF GTPase-activating protein GIT1 (human) (PR_Q9Y2X7)
# >>> ivermectin (CHEBI_6078) - interacts with - ADP-ribosylation factor-like protein 2-binding protein (human) (PR_Q9Y2Y0)
# >>> ivermectin (CHEBI_6078) - interacts with - protein SGT1 homolog (human) (PR_Q9Y2Z0)
# >>> ivermectin (CHEBI_6078) - interacts with - tyrosine--tRNA ligase, mitochondrial (human) (PR_Q9Y2Z4)
# >>> ivermectin (CHEBI_6078) - interacts with - adseverin (human) (PR_Q9Y6U3)
# >>> ivermectin (CHEBI_6078) - interacts with - probable ATP-dependent RNA helicase DDX49 (human) (PR_Q9Y6V7)
# >>> ivermectin (CHEBI_6078) - interacts with - Wiskott-Aldrich syndrome protein family member 2 (human) (PR_Q9Y6W5)
# >>> ivermectin (CHEBI_6078) - interacts with - influenza virus NS1A-binding protein (human) (PR_Q9Y6Y0)
# >>> ivermectin (CHEBI_6078) - interacts with - SEC23-interacting protein (human) (PR_Q9Y6Y8)

# %% [markdown]
# ***
# ***
#
# #### myocardial infarction (`MONDO_0005068`) <a class="anchor" id="mondo_0005068"></a>

# %%
node = [obo.MONDO_0005068]
degree = str(kg.degree(node[0]))
in_edges = str(len(kg.in_edges(node[0])))
out_edges = str(len(kg.out_edges(node[0])))
print('This node has degree {}, which consists of {} in-edges and {} out-edges'.format(degree, in_edges, out_edges))
# Out:
# This node has degree 778, which consists of 395 in-edges and 383 out-edges
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# *Ancestors*

# %%
# examine the node's ancestors
prefix = 'MONDO'
mondo0005068_anc_dict = processes_ancestor_path_list(nx_ancestor_search(kg, node.copy(), prefix))
mondo0005068_ancestors = format_path_ancestors(mondo0005068_anc_dict, node_data_dict)

# %%
# visualize hierarchy
# visualize_ancestor_tree(mondo0005068_ancestors)  # using static viz
g = visualize_kg_output(kg, mondo0005068_ancestors, node_data_dict)
g.force_atlas_2based(gravity=-25, central_gravity=0.001, spring_length=90, spring_strength=0.08, damping=2, overlap=0)   
g.toggle_physics(True)
g.show('{}_Ancestor_Graph.html'.format(str(node[0]).split('/')[-1]))

# %%
# print results -- nodes are ordered by seniority (higher numbers indicate closer to root)
print('Ancestors of {}'.format(node[0]))
if node_data_dict[str(node[0])]['description'] != 'None': print('- Definition: {}\n'.format(node_data_dict[str(node[0])]['description']))
for level in range(len(mondo0005068_ancestors)):
    print('Level: {}'.format(str(level)))
    for v in mondo0005068_ancestors[::-1][level]:
        v_uri = URIRef(v.split('(')[-1].strip(')'))
        descs = len([a[1] for b in [[[i, n[0]] for j in [kg.get_edge_data(*(n[0], v_uri)).keys()]
                                     for i in j] for n in list(kg.in_edges(v_uri))] for a in b
                     if a[0] == RDFS.subClassOf])
        uri_strip = re.sub('http://purl.obolibrary.org/obo/', '', v)
        print('- {}'.format(uri_strip))
        print('- Definition: {}'.format(node_data_dict[str(v_uri)]['description']))
        print('- Descendants: {}\n'.format(descs + 1))

# %% [markdown]
# *Neighborhood*

# %%
# examine the node's neigborhood (out-edges)
nodes = list(kg.neighbors(node[0]))
neighbors = [a for b in [[[i, n] for j in [kg.get_edge_data(*(node[0], n)).keys()]
                          for i in j] for n in nodes] for a in b]
mondo0005068_sorted_neigbors = sorted(neighbors, key=lambda x: (str(x[1]).split('/')[-1], x[0]))

print('{} has {} neighbors'.format(str(node[0]).split('/')[-1], degree))

# %%
# print node's neigborhood (out-edges)
formats_node_information(node, mondo0005068_sorted_neigbors, node_data_dict, verbose=False)

# %% [markdown]
# ***
#
# #### contact dermatitis (`MONDO_0005480`) <a class="anchor" id="mondo_0005480"></a>

# %%
node = [obo.MONDO_0005480]
degree = str(kg.degree(node[0]))
in_edges = str(len(kg.in_edges(node[0])))
out_edges = str(len(kg.out_edges(node[0])))
print('This node has degree {}, which consists of {} in-edges and {} out-edges'.format(degree, in_edges, out_edges))

# %% [markdown]
# *Ancestors*

# %%
# examine the node's ancestors
prefix = 'MONDO'
mondo0005480_anc_dict = processes_ancestor_path_list(nx_ancestor_search(kg, node.copy(), prefix))
mondo0005480_ancestors = format_path_ancestors(mondo0005480_anc_dict, node_data_dict)

# %%
# visualize hierarchy
# visualize_ancestor_tree(mondo0005480_ancestors)  # using static viz
g = visualize_kg_output(kg, mondo0005480_ancestors, node_data_dict)
g.force_atlas_2based(gravity=-25, central_gravity=0.001, spring_length=90, spring_strength=0.08, damping=2, overlap=0)   
g.toggle_physics(True)
g.show('{}_Ancestor_Graph.html'.format(str(node[0]).split('/')[-1]))

# %%
# print results -- nodes are ordered by seniority (higher numbers indicate closer to root)
print('Ancestors of {}'.format(node[0]))
if node_data_dict[str(node[0])]['description'] != 'None': print('- Definition: {}\n'.format(node_data_dict[str(node[0])]['description']))
for level in range(len(mondo0005480_ancestors)):
    print('Level: {}'.format(str(level)))
    for v in mondo0005480_ancestors[::-1][level]:
        v_uri = URIRef(v.split('(')[-1].strip(')'))
        descs = len([a[1] for b in [[[i, n[0]] for j in [kg.get_edge_data(*(n[0], v_uri)).keys()]
                                     for i in j] for n in list(kg.in_edges(v_uri))] for a in b
                     if a[0] == RDFS.subClassOf])
        uri_strip = re.sub('http://purl.obolibrary.org/obo/', '', v)
        print('- {}'.format(uri_strip))
        print('- Definition: {}'.format(node_data_dict[str(v_uri)]['description']))
        print('- Descendants: {}\n'.format(descs + 1))

# %% [markdown]
# *Neighborhood*

# %%
# examine the node's neigborhood (out-edges)
nodes = list(kg.neighbors(node[0]))
neighbors = [a for b in [[[i, n] for j in [kg.get_edge_data(*(node[0], n)).keys()]
                          for i in j] for n in nodes] for a in b]
mondo0005480_sorted_neigbors = sorted(neighbors, key=lambda x: (str(x[1]).split('/')[-1], x[0]))

print('{} has {} neighbors'.format(str(node[0]).split('/')[-1], degree))

# %%
# print node's neigborhood (out-edges)
formats_node_information(node, mondo0005480_sorted_neigbors, node_data_dict, verbose=False)

# %% [markdown]
# ***
#
# #### Ingrowing Toenail (`HP_0012710`) <a class="anchor" id="hp_0012710"></a>

# %%
node = [obo.HP_0012710]
degree = str(kg.degree(node[0]))
in_edges = str(len(kg.in_edges(node[0])))
out_edges = str(len(kg.out_edges(node[0])))
print('This node has degree {}, which consists of {} in-edges and {} out-edges'.format(degree, in_edges, out_edges))

# %% [markdown]
# *Ancestors*

# %%
# examine the node's ancestors
prefix = 'HP'
hp0012710_anc_dict = processes_ancestor_path_list(nx_ancestor_search(kg, node.copy(), prefix))
hp0012710_ancestors = format_path_ancestors(hp0012710_anc_dict, node_data_dict)

# %%
# visualize hierarchy
# visualize_ancestor_tree(hp0012710_ancestors)  # using static viz
g = visualize_kg_output(kg, hp0012710_ancestors, node_data_dict)
g.force_atlas_2based(gravity=-25, central_gravity=0.001, spring_length=90, spring_strength=0.08, damping=2, overlap=0)   
g.toggle_physics(True)
g.show('{}_Ancestor_Graph.html'.format(str(node[0]).split('/')[-1]))

# %%
# print results -- nodes are ordered by seniority (higher numbers indicate closer to root)
print('Ancestors of {}'.format(node[0]))
if node_data_dict[str(node[0])]['description'] != 'None': print('- Definition: {}\n'.format(node_data_dict[str(node[0])]['description']))
for level in range(len(hp0012710_ancestors)):
    print('Level: {}'.format(str(level)))
    for v in hp0012710_ancestors[::-1][level]:
        v_uri = URIRef(v.split('(')[-1].strip(')'))
        descs = len([a[1] for b in [[[i, n[0]] for j in [kg.get_edge_data(*(n[0], v_uri)).keys()]
                                     for i in j] for n in list(kg.in_edges(v_uri))] for a in b
                     if a[0] == RDFS.subClassOf])
        uri_strip = re.sub('http://purl.obolibrary.org/obo/', '', v)
        print('- {}'.format(uri_strip))
        print('- Definition: {}'.format(node_data_dict[str(v_uri)]['description']))
        print('- Descendants: {}\n'.format(descs + 1))

# %% [markdown]
# *Neighborhood*

# %%
# examine the node's neigborhood (out-edges)
nodes = list(kg.neighbors(node[0]))
neighbors = [a for b in [[[i, n] for j in [kg.get_edge_data(*(node[0], n)).keys()]
                          for i in j] for n in nodes] for a in b]
hp0012710_sorted_neigbors = sorted(neighbors, key=lambda x: (str(x[1]).split('/')[-1], x[0]))

print('{} has {} neighbors'.format(str(node[0]).split('/')[-1], degree))

# %%
# print node's neigborhood (out-edges)
formats_node_information(node, hp0012710_sorted_neigbors, node_data_dict, verbose=False)

# %% [markdown]
# ***
#
# #### Presbyopia (`MONDO_0001330`) <a class="anchor" id="mondo_0001330"></a>

# %%
node = [obo.MONDO_0001330]
degree = str(kg.degree(node[0]))
in_edges = str(len(kg.in_edges(node[0])))
out_edges = str(len(kg.out_edges(node[0])))
print('This node has degree {}, which consists of {} in-edges and {} out-edges'.format(degree, in_edges, out_edges))

# %% [markdown]
# *Ancestors*

# %%
# examine the node's ancestors
prefix = 'MONDO'
mondo0001330_anc_dict = processes_ancestor_path_list(nx_ancestor_search(kg, node.copy(), prefix))
mondo0001330_ancestors = format_path_ancestors(mondo0001330_anc_dict, node_data_dict)

# %%
# visualize hierarchy
# visualize_ancestor_tree(mondo0001330)  # using static viz
g = visualize_kg_output(kg, mondo0001330_ancestors, node_data_dict)
g.force_atlas_2based(gravity=-25, central_gravity=0.001, spring_length=90, spring_strength=0.08, damping=2, overlap=0)   
g.toggle_physics(True)
g.show('{}_Ancestor_Graph.html'.format(str(node[0]).split('/')[-1]))

# %%
# print results -- nodes are ordered by seniority (higher numbers indicate closer to root)
print('Ancestors of {}'.format(node[0]))
if node_data_dict[str(node[0])]['description'] != 'None': print('- Definition: {}\n'.format(node_data_dict[str(node[0])]['description']))
for level in range(len(mondo0001330_ancestors)):
    print('Level: {}'.format(str(level)))
    for v in mondo0001330_ancestors[::-1][level]:
        v_uri = URIRef(v.split('(')[-1].strip(')'))
        descs = len([a[1] for b in [[[i, n[0]] for j in [kg.get_edge_data(*(n[0], v_uri)).keys()]
                                     for i in j] for n in list(kg.in_edges(v_uri))] for a in b
                     if a[0] == RDFS.subClassOf])
        uri_strip = re.sub('http://purl.obolibrary.org/obo/', '', v)
        print('- {}'.format(uri_strip))
        print('- Definition: {}'.format(node_data_dict[str(v_uri)]['description']))
        print('- Descendants: {}\n'.format(descs + 1))

# %% [markdown]
# *Neighborhood*

# %%
# examine the node's neigborhood (out-edges)
nodes = list(kg.neighbors(node[0]))
neighbors = [a for b in [[[i, n] for j in [kg.get_edge_data(*(node[0], n)).keys()]
                          for i in j] for n in nodes] for a in b]
mondo0001330_sorted_neigbors = sorted(neighbors, key=lambda x: (str(x[1]).split('/')[-1], x[0]))

print('{} has {} neighbors'.format(str(node[0]).split('/')[-1], degree))

# %%
# print node's neigborhood (out-edges)
formats_node_information(node, mondo0001330_sorted_neigbors, node_data_dict, verbose=False)

# %% [markdown]
# ***
#
# #### Neurotoxicity (`MONDO_0005527`) <a class="anchor" id="mondo_0005527"></a>

# %%
node = [obo.MONDO_0005527]
degree = str(kg.degree(node[0]))
in_edges = str(len(kg.in_edges(node[0])))
out_edges = str(len(kg.out_edges(node[0])))
print('This node has degree {}, which consists of {} in-edges and {} out-edges'.format(degree, in_edges, out_edges))

# %% [markdown]
# *Ancestors*

# %%
# examine the node's ancestors
prefix = 'MONDO'
mondo0005527_anc_dict = processes_ancestor_path_list(nx_ancestor_search(kg, node.copy(), prefix))
mondo0005527_ancestors = format_path_ancestors(mondo0005527_anc_dict, node_data_dict)

# %%
# visualize hierarchy
# visualize_ancestor_tree(mondo0005527_ancestors)  # using static viz
g = visualize_kg_output(kg, mondo0005527_ancestors, node_data_dict)
g.force_atlas_2based(gravity=-25, central_gravity=0.001, spring_length=90, spring_strength=0.08, damping=2, overlap=0)   
g.toggle_physics(True)
g.show('{}_Ancestor_Graph.html'.format(str(node[0]).split('/')[-1]))

# %%
# print results -- nodes are ordered by seniority (higher numbers indicate closer to root)
print('Ancestors of {}'.format(node[0]))
if node_data_dict[str(node[0])]['description'] != 'None': print('- Definition: {}\n'.format(node_data_dict[str(node[0])]['description']))
for level in range(len(mondo0005527_ancestors)):
    print('Level: {}'.format(str(level)))
    for v in mondo0005527_ancestors[::-1][level]:
        v_uri = URIRef(v.split('(')[-1].strip(')'))
        descs = len([a[1] for b in [[[i, n[0]] for j in [kg.get_edge_data(*(n[0], v_uri)).keys()]
                                     for i in j] for n in list(kg.in_edges(v_uri))] for a in b
                     if a[0] == RDFS.subClassOf])
        uri_strip = re.sub('http://purl.obolibrary.org/obo/', '', v)
        print('- {}'.format(uri_strip))
        print('- Definition: {}'.format(node_data_dict[str(v_uri)]['description']))
        print('- Descendants: {}\n'.format(descs + 1))

# %% [markdown]
# *Neighborhood*

# %%
# examine the node's neigborhood (out-edges)
nodes = list(kg.neighbors(node[0]))
neighbors = [a for b in [[[i, n] for j in [kg.get_edge_data(*(node[0], n)).keys()]
                          for i in j] for n in nodes] for a in b]
mondo0005527_sorted_neigbors = sorted(neighbors, key=lambda x: (str(x[1]).split('/')[-1], x[0]))

print('{} has {} neighbors'.format(str(node[0]).split('/')[-1], degree))

# %%
# print node's neigborhood (out-edges)
formats_node_information(node, mondo0005527_sorted_neigbors, node_data_dict, verbose=False)

# %% [markdown]
# <br>
#
# ### Path-Level Characterization  <a class="anchor" id="path-level"></a>
#
# ***
#
# - **Positive Relationship:**
#   - [`lisinopril` ([CHEBI_6503](http://purl.obolibrary.org/obo/CHEBI_6503)) and `myocardial infarction` ([MONDO_0005068](http://purl.obolibrary.org/obo/MONDO_0005068))](#path1)
#
# - **Negative Relationships:**
#   - [`lisinopril` ([CHEBI_6503](http://purl.obolibrary.org/obo/CHEBI_6503)) and `contact dermatitis` ([MONDO_0005480](http://purl.obolibrary.org/obo/MONDO_0005480))](#path2)
#   - [`lisinopril` ([CHEBI_6503](http://purl.obolibrary.org/obo/CHEBI_6503)) and `ingrowing toenails` ([HP_0012710](http://purl.obolibrary.org/obo/MONDO_0005480))](#path3)
#   - [`lisinopril` ([CHEBI_6503](http://purl.obolibrary.org/obo/CHEBI_6503)) and `presbyopia` ([MONDO_0001330](http://purl.obolibrary.org/obo/MONDO_0001330))](#path4)
#
# - **Unknown Relationships:**
#   - [`ivermectin` ([CHEBI_6078](http://purl.obolibrary.org/obo/CHEBI_6078)) and `neurotoxicity` ([MONDO_0005527](http://purl.obolibrary.org/obo/MONDO_0005527))](#path5)

# %% [markdown]
# ***
#
# ### Positive Relationships
#
# When examining `lisinopril` and `myocardial infarction`. We observed that this pair had an efficiency of `1.0` and a single shortest path of length `1`.

# %% [markdown]
# ***
#
# #### lisinopril (`CHEBI_6503`) and myocardial infarction (`MONDO_0005068`) <a class="anchor" id="path1"></a>

# %%
s = obo.CHEBI_6503; t = obo.MONDO_0005068
try:
    kg_orientation = kg; ind = 'directed'
    spl_d = nx.shortest_path_length(kg, source=s, target=t)  
    print('The shortest path length is: {} ({})'.format(str(spl_d), ind))
    # get efficiency (measure of how efficiently information is exchanged between nodes)
    eff = nx.efficiency(undirected_kg, s, t)
    print('The efficiency between the nodes is: {}'.format(str(eff)))
except nx.NetworkXNoPath:
    print('There is no path between {} and {}'.format(str(s), str(t)))
    kg_orientation = undirected_kg; ind = 'undirected'
    spl_d = nx.shortest_path_length(undirected_kg, source=s, target=t)
    print('The shortest path length is: {} ({})'.format(str(spl_d), ind))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 s = obo.CHEBI_6503; t = obo.MONDO_0005068
#       2 try:
#       3     kg_orientation = kg; ind = 'directed'
#
# NameError: name 'obo' is not defined

# %%
shortest_paths1 = list(nx.all_shortest_paths(kg_orientation, s, t))
p_len = nx.shortest_path_length(kg_orientation, source=s, target=t)
v = 'is' if len(shortest_paths1) == 1 else 'are'
print('There {} {} shortest paths of length {}'.format(v, str(len(shortest_paths1)), str(p_len)))

# %%
formats_path_information(kg=kg_orientation,
                         paths=shortest_paths1,
                         path_type='shortest',
                         metadata_func=metadata_formatter,
                         metadata_dict=None,
                         node_metadata=node_data_dict,
                         verbose=False,
                         rand=True,
                         sample_size=10)

# %% [markdown]
# *Simple Paths*

# %%
# simple paths (i.e., no repeated nodes)
simple_paths1 = []; counter = 0
for path in tqdm(nx.all_simple_paths(kg_orientation, source=s, target=t, cutoff=5)):
    simple_paths1 += [path]
    if counter == 25: break
    else: counter += 1

# %%
# print random sample of n simple paths
formats_path_information(kg=kg_orientation,
                         paths=simple_paths1,
                         path_type='simple',
                         metadata_func=metadata_formatter,
                         metadata_dict=None,
                         node_metadata=node_data_dict,
                         verbose=False,
                         rand=True,
                         sample_size=10)

# %% [markdown]
# <br>
#
# ***
#
# ### Negative Relationships
#
# When examining the following negative relationships:
# 1. `lisinopril` and `contact dermatitis`. This pair had an efficiency of `0.33` and `14` shortest paths of length 4.
# 2. `lisinopril` and `ingrowing toenails`. This pair had an efficiency of `0.33` and no shortest paths.
# 3.  `lisinopril` and `presbyopia`. This pair had an efficiency of `0.25` and no shortest paths.

# %% [markdown]
# ***
# #### lisinopril (`CHEBI_6503`) and contact dermatitis (`MONDO_0005480`)  <a class="anchor" id="path2"></a>

# %%
s = obo.CHEBI_6503; t = obo.MONDO_0005480
try:
    kg_orientation = kg; ind = 'directed'
    spl_d = nx.shortest_path_length(kg, source=s, target=t)  
    print('The shortest path length is: {} ({})'.format(str(spl_d), ind))
    # get efficiency (measure of how efficiently information is exchanged between nodes)
    eff = nx.efficiency(undirected_kg, s, t)
    print('The efficiency between the nodes is: {}'.format(str(eff)))
except nx.NetworkXNoPath:
    print('There is no path between {} and {}'.format(str(s), str(t)))
    kg_orientation = undirected_kg; ind = 'undirected'
    spl_d = nx.shortest_path_length(undirected_kg, source=s, target=t)
    print('The shortest path length is: {} ({})'.format(str(spl_d), ind))

# %%
shortest_paths2 = list(nx.all_shortest_paths(kg_orientation, s, t))
p_len = nx.shortest_path_length(kg_orientation, source=s, target=t)
v = 'is' if len(shortest_paths2) == 1 else 'are'
print('There {} {} shortest paths of length {}'.format(v, str(len(shortest_paths2)), str(p_len)))

# %%
formats_path_information(kg=kg_orientation,
                         paths=shortest_paths2,
                         path_type='shortest',
                         metadata_func=metadata_formatter,
                         metadata_dict=None,
                         node_metadata=node_data_dict,
                         verbose=False,
                         rand=True,
                         sample_size=10)

# %% [markdown]
# *Simple Paths*

# %%
# simple paths (i.e., no repeated nodes)
simple_paths2 = []; counter = 0
for path in tqdm(nx.all_simple_paths(kg_orientation, source=s, target=t, cutoff=5)):
    simple_paths2 += [path]
    if counter == 25: break
    else: counter += 1

# %%
# simple paths (i.e., no repeated nodes)
formats_path_information(kg=kg_orientation,
                         paths=simple_paths2,
                         path_type='simple',
                         metadata_func=metadata_formatter,
                         metadata_dict=None,
                         node_metadata=node_data_dict,
                         verbose=False,
                         rand=True,
                         sample_size=10)

# %% [markdown]
# ***
# #### lisinopril (`CHEBI_6503`) and ingrowing toenails (`HP_0012710`)  <a class="anchor" id="path3"></a>

# %%
s = obo.CHEBI_6503; t = obo.HP_0012710
try:
    kg_orientation = kg; ind = 'directed'
    spl_d = nx.shortest_path_length(kg, source=s, target=t)  
    print('The shortest path length is: {} ({})'.format(str(spl_d), ind))
    # get efficiency (measure of how efficiently information is exchanged between nodes)
    eff = nx.efficiency(undirected_kg, s, t)
    print('The efficiency between the nodes is: {}'.format(str(eff)))
except nx.NetworkXNoPath:
    print('There is no path between {} and {}'.format(str(s), str(t)))
    kg_orientation = undirected_kg; ind = 'undirected'
    spl_d = nx.shortest_path_length(undirected_kg, source=s, target=t)
    print('The shortest path length is: {} ({})'.format(str(spl_d), ind))

# %%
shortest_paths4 = list(nx.all_shortest_paths(kg_orientation, s, t))
p_len = nx.shortest_path_length(kg_orientation, source=s, target=t)
v = 'is' if len(shortest_paths4) == 1 else 'are'
print('There {} {} shortest paths of length {}'.format(v, str(len(shortest_paths4)), str(p_len)))

# %%
formats_path_information(kg=kg_orientation,
                         paths=shortest_paths4,
                         path_type='shortest',
                         metadata_func=metadata_formatter,
                         metadata_dict=None,
                         node_metadata=node_data_dict,
                         verbose=False,
                         rand=True,
                         sample_size=10)

# %% [markdown]
# *Simple Paths*

# %%
# simple paths (i.e., no repeated nodes)
simple_paths3 = []; counter = 0
for path in tqdm(nx.all_simple_paths(kg_orientation, source=s, target=t, cutoff=5)):
    simple_paths3 += [path]
    if counter == 10: break
    else: counter += 1

# %%
# simple paths (i.e., no repeated nodes)
formats_path_information(kg=kg_orientation,
                         paths=simple_paths3,
                         path_type='simple',
                         metadata_func=metadata_formatter,
                         metadata_dict=None,
                         node_metadata=node_data_dict,
                         verbose=False,
                         rand=True,
                         sample_size=10)

# %% [markdown]
# ***
# #### lisinopril (`CHEBI_6503`) and  presbyopia (`MONDO_0001330`)  <a class="anchor" id="path4"></a>

# %%
s = obo.CHEBI_6503; t = obo.MONDO_0001330
try:
    kg_orientation = kg; ind = 'directed'
    spl_d = nx.shortest_path_length(kg, source=s, target=t)  
    print('The shortest path length is: {} ({})'.format(str(spl_d), ind))
    # get efficiency (measure of how efficiently information is exchanged between nodes)
    eff = nx.efficiency(undirected_kg, s, t)
    print('The efficiency between the nodes is: {}'.format(str(eff)))
except nx.NetworkXNoPath:
    print('There is no path between {} and {}'.format(str(s), str(t)))
    kg_orientation = undirected_kg; ind = 'undirected'
    spl_d = nx.shortest_path_length(undirected_kg, source=s, target=t)
    print('The shortest path length is: {} ({})'.format(str(spl_d), ind))

# %%
shortest_paths4 = list(nx.all_shortest_paths(kg_orientation, s, t))
p_len = nx.shortest_path_length(kg_orientation, source=s, target=t)
v = 'is' if len(shortest_paths4) == 1 else 'are'
print('There {} {} shortest paths of length {}'.format(v, str(len(shortest_paths4)), str(p_len)))

# %%
formats_path_information(kg=kg_orientation,
                         paths=shortest_paths4,
                         path_type='shortest',
                         metadata_func=metadata_formatter,
                         metadata_dict=None,
                         node_metadata=node_data_dict,
                         verbose=False,
                         rand=True,
                         sample_size=10)

# %% [markdown]
# *Simple Paths*

# %%
# simple paths (i.e., no repeated nodes)
simple_paths4 = []; counter = 0
for path in tqdm(nx.all_simple_paths(kg_orientation, source=s, target=t, cutoff=5)):
    simple_paths4 += [path]
    if counter == 25: break
    else: counter += 1

# %%
# simple paths (i.e., no repeated nodes)
formats_path_information(kg=kg_orientation,
                         paths=simple_paths4,
                         path_type='simple',
                         metadata_func=metadata_formatter,
                         metadata_dict=None,
                         node_metadata=node_data_dict,
                         verbose=False,
                         rand=True,
                         sample_size=10)

# %% [markdown]
# <br>
#
# ***
#
# ### Unknown Relationships

# %% [markdown]
# ***
# #### ivermectin (`CHEBI_6078`) and neurotoxicity (`MONDO_0005527`)  <a class="anchor" id="path5"></a>
#
# When examining `ivermectin` and `neurotoxicity`. We observed that this pair had an efficiency of `1.0` and a single shortest path of length `1`.

# %%
s = obo.CHEBI_6078; t = obo.MONDO_0005527
try:
    kg_orientation = kg; ind = 'directed'
    spl_d = nx.shortest_path_length(kg, source=s, target=t)  
    print('The shortest path length is: {} ({})'.format(str(spl_d), ind))
    # get efficiency (measure of how efficiently information is exchanged between nodes)
    eff = nx.efficiency(undirected_kg, s, t)
    print('The efficiency between the nodes is: {}'.format(str(eff)))
except nx.NetworkXNoPath:
    print('There is no path between {} and {}'.format(str(s), str(t)))
    kg_orientation = undirected_kg; ind = 'undirected'
    spl_d = nx.shortest_path_length(undirected_kg, source=s, target=t)
    print('The shortest path length is: {} ({})'.format(str(spl_d), ind))

# %%
shortest_paths5 = list(nx.all_shortest_paths(kg_orientation, s, t))
p_len = nx.shortest_path_length(kg_orientation, source=s, target=t)
v = 'is' if len(shortest_paths5) == 1 else 'are'
print('There {} {} shortest paths of length {}'.format(v, str(len(shortest_paths5)), str(p_len)))

# %%
formats_path_information(kg=kg_orientation,
                         paths=shortest_paths5,
                         path_type='shortest',
                         metadata_func=metadata_formatter,
                         metadata_dict=None,
                         node_metadata=node_data_dict,
                         verbose=False,
                         rand=True,
                         sample_size=10)

# %% [markdown]
# *Simple Paths*

# %%
# simple paths (i.e., no repeated nodes)
simple_paths5 = []; counter = 0
for path in tqdm(nx.all_simple_paths(undirected_kg, source=s, target=t, cutoff=5)):
    simple_paths5 += [path]
    if counter == 25: break
    else: counter += 1

# %%
# simple paths (i.e., no repeated nodes) -- forcing the kg to be undirected in order to get output
formats_path_information(kg=undirected_kg,
                         paths=simple_paths5,
                         path_type='simple',
                         metadata_func=metadata_formatter,
                         metadata_dict=None,
                         node_metadata=node_data_dict,
                         verbose=False,
                         rand=True,
                         sample_size=10)

# %% [markdown]
# <br>
#
# ***
# ***
#
# This Notebook is part of the [**PheKnowLator Ecosystem**](https://zenodo.org/communities/pheknowlator-ecosystem/edit/)
#
# ```
# @misc{callahan_tj_2019_3401437,
#   author       = {Callahan, TJ},
#   title        = {PheKnowLator},
#   month        = mar,
#   year         = 2019,
#   doi          = {10.5281/zenodo.3401437},
#   url          = {https://doi.org/10.5281/zenodo.3401437}
# }
# ```
#
# ***

# %% [markdown]
# <br>
#
# ***
# ***
#
# # Additional Utility: Finding Nodes by Label
#
# When working with the PheKnowLator knowledge graph, it's often useful to find nodes by their label rather than by URI. Below is a simple function to search for nodes by their label name.

# %%
def find_nodes_by_label(kg, node_metadata_dict, search_text, case_sensitive=False, exact_match=False):
    """
    Search for nodes in the knowledge graph by their label.
    
    Args:
        kg: A networkx MultiDiGraph object representing the knowledge graph.
        node_metadata_dict: A dictionary containing node metadata, including labels.
        search_text: The label text to search for.
        case_sensitive: Boolean indicating whether the search should be case-sensitive (default=False).
        exact_match: Boolean indicating whether to match the entire label exactly (default=False).
    
    Returns:
        A list of tuples containing (node_uri, label, node_type) for matching nodes.
    """
    results = []
    
    # Convert search text to lowercase if not case sensitive
    if not case_sensitive:
        search_text = search_text.lower()
    
    # Iterate through the node metadata dictionary
    for node_uri, metadata in node_metadata_dict.items():
        label = metadata.get('label', '')
        
        # Skip if no label
        if not label:
            continue
        
        # Perform matching based on parameters
        if exact_match:
            if case_sensitive:
                matches = (label == search_text)
            else:
                matches = (label.lower() == search_text)
        else:
            if case_sensitive:
                matches = (search_text in label)
            else:
                matches = (search_text.lower() in label.lower())
        
        if matches:
            # Determine node type from URI if possible
            node_type = None
            if 'http://purl.obolibrary.org/obo/' in node_uri:
                # Extract prefix from OBO URI (e.g., CHEBI, MONDO, HP)
                parts = node_uri.split('/')[-1].split('_')
                if len(parts) > 0:
                    node_type = parts[0]
            
            results.append((node_uri, label, node_type))
    
    # Sort results by label for better readability
    results.sort(key=lambda x: x[1])
    return results

# %% [markdown]
# ## Example Usage
#
# Let's demonstrate how to use this function to find nodes by their labels. We'll try a few different examples:
#
# 1. Search for a drug by its generic name (e.g., "lisinopril")
# 2. Search for a disease using a partial name (e.g., "myocardial")
# 3. Search for a phenotype with case-insensitive matching (e.g., "toenail")

# %%
# Example 1: Search for a drug by exact name (lisinopril)
drug_results = find_nodes_by_label(kg, node_data_dict, "lisinopril", exact_match=True)
print(f"Found {len(drug_results)} nodes with the exact label 'lisinopril':")
for uri, label, node_type in drug_results:
    print(f"- {label} ({node_type}): {uri}")
    
    # Get this as a proper node object for further exploration
    if 'http://purl.obolibrary.org/obo/' in uri:
        node_uri = URIRef(uri)
        print(f"  Degree: {kg.degree(node_uri)} (in: {len(kg.in_edges(node_uri))}, out: {len(kg.out_edges(node_uri))})")
    print("")

# %%
# Example 2: Search for a disease with partial name matching (myocardial)
disease_results = find_nodes_by_label(kg, node_data_dict, "myocardial", exact_match=False)
print(f"Found {len(disease_results)} nodes containing 'myocardial' in their label:")
for i, (uri, label, node_type) in enumerate(disease_results[:10]):  # Show first 10 results
    print(f"- {label} ({node_type}): {uri}")
    
if len(disease_results) > 10:
    print(f"... and {len(disease_results) - 10} more results")
